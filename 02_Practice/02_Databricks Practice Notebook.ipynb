# %% [markdown]
# # Practice Notebook

# %% [markdown]
# ## This notebook is being used as a practicing and documenting my learning in `Databricks`

# %% [markdown]
# ### Code in Python

# %%
# Python
df = spark.table('orders')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### Code in SQL

# %%
# %sql
SELECT *
FROM orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
